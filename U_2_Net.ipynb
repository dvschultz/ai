# %% [markdown]
# <a href="https://colab.research.google.com/github/dvschultz/ai/blob/master/U_2_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NathanUA/U-2-Net
# %cd U-2-Net
# %mkdir saved_models
# %mkdir saved_models/u2net
# !gdown --id 1ao1ovG1Qtx4b7EoskHXmi2E9rp5CHLcZ -O /content/U-2-Net/saved_models/u2net/u2net.pth
# Out:
# Cloning into 'U-2-Net'...
# remote: Enumerating objects: 241, done.
# remote: Total 241 (delta 0), reused 0 (delta 0), pack-reused 241
# Receiving objects: 100% (241/241), 8.25 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# /content/U-2-Net
# Downloading...
# From: https://drive.google.com/uc?id=1ao1ovG1Qtx4b7EoskHXmi2E9rp5CHLcZ
# To: /content/U-2-Net/saved_models/u2net/u2net.pth
# 176MB [00:01, 99.5MB/s]

# %% [markdown]
# This command just empties the results folders of their default images

# %%
# !rm /content/U-2-Net/test_data/u2net_results/*
# !rm /content/U-2-Net/test_data/test_images/*

# %% [markdown]
# Add your own images to the `U-2-Net/test_data/test_images/` folder. Then run the following command.

# %%
# !python u2net_test.py
# Out:
# ['/content/U-2-Net/test_data/test_images/out296.png', '/content/U-2-Net/test_data/test_images/out246.png', '/content/U-2-Net/test_data/test_images/out241.png', '/content/U-2-Net/test_data/test_images/out21.png', '/content/U-2-Net/test_data/test_images/out72.png', '/content/U-2-Net/test_data/test_images/out44.png', '/content/U-2-Net/test_data/test_images/out181.png', '/content/U-2-Net/test_data/test_images/out176.png', '/content/U-2-Net/test_data/test_images/out49.png', '/content/U-2-Net/test_data/test_images/out101.png', '/content/U-2-Net/test_data/test_images/out104.png', '/content/U-2-Net/test_data/test_images/out331.png', '/content/U-2-Net/test_data/test_images/out256.png', '/content/U-2-Net/test_data/test_images/out267.png', '/content/U-2-Net/test_data/test_images/out244.png', '/content/U-2-Net/test_data/test_images/out69.png', '/content/U-2-Net/test_data/test_images/out156.png', '/content/U-2-Net/test_data/test_images/out272.png', '/content/U-2-Net/test_data/test_images/out148.png', '/content/U-2-Net/test_data/test_images/out298.png', '/content/U-2-Net/test_data/test_images/out350.png', '/content/U-2-Net/test_data/test_images/out106.png', '/content/U-2-Net/test_data/test_images/out84.png', '/content/U-2-Net/test_data/test_images/out329.png', '/content/U-2-Net/test_data/test_images/out121.png', '/content/U-2-Net/test_data/test_images/out54.png', '/content/U-2-Net/test_data/test_images/out208.png', '/content/U-2-Net/test_data/test_images/out248.png', '/content/U-2-Net/test_data/test_images/out57.png', '/content/U-2-Net/test_data/test_images/out306.png', '/content/U-2-Net/test_data/test_images/out366.png', '/content/U-2-Net/test_data/test_images/out147.png', '/content/U-2-Net/test_data/test_images/out10.png', '/content/U-2-Net/test_data/test_images/out200.png', '/content/U-2-Net/test_data/test_images/out315.png', '/content/U-2-Net/test_data/test_images/out330.png', '/content/U-2-Net/test_data/test_images/out348.png', '/content/U-2-Net/test_data/test_images/out278.png', '/content/U-2-Net/test_data/test_images/out152.png', '/content/U-2-Net/test_data/test_images/out237.png', '/content/U-2-Net/test_data/test_images/out11.png', '/content/U-2-Net/test_data/test_images/out129.png', '/content/U-2-Net/test_data/test_images/out34.png', '/content/U-2-Net/test_data/test_images/out251.png', '/content/U-2-Net/test_data/test_images/out132.png', '/content/U-2-Net/test_data/test_images/out116.png', '/content/U-2-Net/test_data/test_images/out94.png', '/content/U-2-Net/test_data/test_images/out168.png', '/content/U-2-Net/test_data/test_images/out77.png', '/content/U-2-Net/test_data/test_images/out61.png', '/content/U-2-Net/test_data/test_images/out323.png', '/content/U-2-Net/test_data/test_images/out100.png', '/content/U-2-Net/test_data/test_images/out218.png', '/content/U-2-Net/test_data/test_images/out236.png', '/content/U-2-Net/test_data/test_images/out194.png', '/content/U-2-Net/test_data/test_images/out310.png', '/content/U-2-Net/test_data/test_images/out155.png', '/content/U-2-Net/test_data/test_images/out312.png', '/content/U-2-Net/test_data/test_images/out47.png', '/content/U-2-Net/test_data/test_images/out191.png', '/content/U-2-Net/test_data/test_images/out265.png', '/content/U-2-Net/test_data/test_images/out158.png', '/content/U-2-Net/test_data/test_images/out161.png', '/content/U-2-Net/test_data/test_images/out262.png', '/content/U-2-Net/test_data/test_images/out281.png', '/content/U-2-Net/test_data/test_images/out154.png', '/content/U-2-Net/test_data/test_images/out82.png', '/content/U-2-Net/test_data/test_images/out322.png', '/content/U-2-Net/test_data/test_images/out157.png', '/content/U-2-Net/test_data/test_images/out30.png', '/content/U-2-Net/test_data/test_images/out185.png', '/content/U-2-Net/test_data/test_images/out356.png', '/content/U-2-Net/test_data/test_images/out346.png', '/content/U-2-Net/test_data/test_images/out150.png', '/content/U-2-Net/test_data/test_images/out139.png', '/content/U-2-Net/test_data/test_images/o ...
# ...load U2NET---173.6 MB
# inferencing: out296.png
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2796: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1569: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# inferencing: out246.png
# inferencing: out241.png
# inferencing: out21.png
# inferencing: out72.png
# inferencing: out44.png
# inferencing: out181.png
# inferencing: out176.png
# inferencing: out49.png
# inferencing: out101.png
# inferencing: out104.png
# inferencing: out331.png
# inferencing: out256.png
# inferencing: out267.png
# inferencing: out244.png
# inferencing: out69.png
# inferencing: out156.png
# inferencing: out272.png
# inferencing: out148.png
# inferencing: out298.png
# inferencing: out350.png
# inferencing: out106.png
# inferencing: out84.png
# inferencing: out329.png
# inferencing: out121.png
# inferencing: out54.png
# inferencing: out208.png
# inferencing: out248.png
# inferencing: out57.png
# inferencing: out306.png
# inferencing: out366.png
# inferencing: out147.png
# inferencing: out10.png
# inferencing: out200.png
# inferencing: out315.png
# inferencing: out330.png
# inferencing: out348.png
# inferencing: out278.png
# inferencing: out152.png
# inferencing: out237.png
# inferencing: out11.png
# inferencing: out129.png
# inferencing: out34.png
# inferencing: out251.png
# inferencing: out132.png
# inferencing: out116.png
# inferencing: out94.png
# inferencing: out168.png
# inferencing: out77.png
# inferencing: out61.png
# inferencing: out323.png
# inferencing: out100.png
# inferencing: out218.png
# inferencing: out236.png
# inferencing: out194.png
# inferencing: out310.png
# inferencing: out155.png
# inferencing: out312.png
# inferencing: out47.png
# inferencing: out191.png
# inferencing: out265.png
# inferencing: out158.png
# inferencing: out161.png
# inferencing: out262.png
# inferencing: out281.png
# inferencing: out154.png
# inferencing: out82.png
# inferencing: out322.png
# inferencing: out157.png
# inferencing: out30.png
# inferencing: out185.png
# inferencing: out356.png
# inferencing: out346.png
# inferencing: out150.png
# inferencing: out139.png
# inferencing: out20.png
# inferencing: out123.png
# inferencing: out247.png
# inferencing: out60.png
# inferencing: out78.png
# inferencing: out56.png
# inferencing: out363.png
# inferencing: out126.png
# inferencing: out313.png
# inferencing: out167.png
# inferencing: out326.png
# inferencing: out111.png
# inferencing: out261.png
# inferencing: out299.png
# inferencing: out110.png
# inferencing: out233.png
# inferencing: out25.png
# inferencing: out137.png
# inferencing: out270.png
# inferencing: out174.png
# inferencing: out112.png
# inferencing: out141.png
# inferencing: out325.png
# inferencing: out319.png
# inferencing: out37.png
# inferencing: out230.png
# inferencing: out342.png
# inferencing: out216.png
# inferencing: out1.png
# inferencing: out231.png
# inferencing: out36.png
# inferencing: out351.png
# inferencing: out28.png
# inferencing: out249.png
# inferencing: out149.png
# inferencing: out340.png
# inferencing: out14.png
# inferencing: out321.png
# inferencing: out206.png
# inferencing: out52.png
# inferencing: out96.png
# inferencing: out195.png
# inferencing: out279.png
# inferencing: out275.png
# inferencing: out215.png
# inferencing: out303.png
# inferencing: out97.png
# inferencing: out183.png
# inferencing: out328.png
# inferencing: out8.png
# inferencing: out252.png
# inferencing: out193.png
# inferencing: out13.png
# inferencing: out115.png
# inferencing: out102.png
# inferencing: out240.png
# inferencing: out229.png
# inferencing: out362.png
# inferencing: out316.png
# inferencing: out292.png
# inferencing: out184.png
# inferencing: out80.png
# inferencing: out368.png
# inferencing: out170.png
# inferencing: out4.png
# inferencing: out53.png
# inferencing: out186.png
# inferencing: out124.png
# inferencing: out15.png
# inferencing: out364.png
# inferencing: out352.png
# inferencing: out66.png
# inferencing: out64.png
# inferencing: out317.png
# inferencing: out95.png
# inferencing: out24.png
# inferencing: out59.png
# inferencing: out196.png
# inferencing: out232.png
# inferencing: out276.png
# inferencing: out349.png
# inferencing: out75.png
# inferencing: out234.png
# inferencing: out273.png
# inferencing: out98.png
# inferencing: out5.png
# inferencing: out345.png
# inferencing: out308.png
# inferencing: out58.png
# inferencing: out177.png
# inferencing: out171.png
# inferencing: out197.png
# inferencing: out214.png
# inferencing: out219.png
# inferencing: out213.png
# inferencing: out288.png
# inferencing: out12.png
# inferencing: out32.png
# inferencing: out88.png
# inferencing: out337.png
# inferencing: out86.png
# inferencing: out179.png
# inferencing: out63.png
# inferencing: out204.png
# inferencing: out74.png
# inferencing: out119.png
# inferencing: out360.png
# inferencing: out182.png
# inferencing: out62.png
# inferencing: out333.png
# inferencing: out188.png
# inferencing: out180.png
# inferencing: out160.png
# inferencing: out46.png
# inferencing: out201.png
# inferencing: out255.png
# inferencing: out199.png
# inferencing: out113.png
# inferencing: out280.png
# inferencing: out203.png
# inferencing: out212.png
# inferencing: out211.png
# inferencing: out210.png
# inferencing: out198.png
# inferencing: out271.png
# inferencing: out40.png
# inferencing: out332.png
# inferencing: out130.png
# inferencing: out300.png
# inferencing: out169.png
# inferencing: out6.png
# inferencing: out202.png
# inferencing: out35.png
# inferencing: out207.png
# inferencing: out178.png
# inferencing: out105.png
# inferencing: out245.png
# inferencing: out277.png
# inferencing: out238.png
# inferencing: out217.png
# inferencing: out254.png
# inferencing: out367.png
# inferencing: out295.png
# inferencing: out9.png
# inferencing: out187.png
# inferencing: out357.png
# inferencing: out221.png
# inferencing: out266.png
# inferencing: out257.png
# inferencing: out344.png
# inferencing: out189.png
# inferencing: out68.png
# inferencing: out128.png
# inferencing: out165.png
# inferencing: out120.png
# inferencing: out175.png
# inferencing: out225.png
# inferencing: out311.png
# inferencing: out284.png
# inferencing: out365.png
# inferencing: out226.png
# inferencing: out263.png
# inferencing: out38.png
# inferencing: out144.png
# inferencing: out297.png
# inferencing: out227.png
# inferencing: out242.png
# inferencing: out142.png
# inferencing: out305.png
# inferencing: out135.png
# inferencing: out220.png
# inferencing: out29.png
# inferencing: out71.png
# inferencing: out93.png
# inferencing: out143.png
# inferencing: out209.png
# inferencing: out274.png
# inferencing: out258.png
# inferencing: out76.png
# inferencing: out286.png
# inferencing: out259.png
# inferencing: out318.png
# inferencing: out2.png
# inferencing: out136.png
# inferencing: out173.png
# inferencing: out125.png
# inferencing: out153.png
# inferencing: out264.png
# inferencing: out283.png
# inferencing: out358.png
# inferencing: out190.png
# inferencing: out91.png
# inferencing: out260.png
# inferencing: out134.png
# inferencing: out67.png
# inferencing: out222.png
# inferencing: out361.png
# inferencing: out114.png
# inferencing: out107.png
# inferencing: out140.png
# inferencing: out324.png
# inferencing: out282.png
# inferencing: out31.png
# inferencing: out291.png
# inferencing: out302.png
# inferencing: out117.png
# inferencing: out235.png
# inferencing: out163.png
# inferencing: out293.png
# inferencing: out355.png
# inferencing: out55.png
# inferencing: out353.png
# inferencing: out327.png
# inferencing: out243.png
# inferencing: out359.png
# inferencing: out131.png
# inferencing: out87.png
# inferencing: out336.png
# inferencing: out223.png
# inferencing: out70.png
# inferencing: out172.png
# inferencing: out19.png
# inferencing: out287.png
# inferencing: out27.png
# inferencing: out73.png
# inferencing: out253.png
# inferencing: out51.png
# inferencing: out122.png
# inferencing: out354.png
# inferencing: out159.png
# inferencing: out7.png
# inferencing: out304.png
# inferencing: out103.png
# inferencing: out89.png
# inferencing: out83.png
# inferencing: out307.png
# inferencing: out22.png
# inferencing: out16.png
# inferencing: out108.png
# inferencing: out224.png
# inferencing: out85.png
# inferencing: out369.png
# inferencing: out33.png
# inferencing: out146.png
# inferencing: out289.png
# inferencing: out92.png
# inferencing: out334.png
# inferencing: out341.png
# inferencing: out81.png
# inferencing: out166.png
# inferencing: out79.png
# inferencing: out133.png
# inferencing: out26.png
# inferencing: out339.png
# inferencing: out127.png
# inferencing: out17.png
# inferencing: out23.png
# inferencing: out268.png
# inferencing: out45.png
# inferencing: out162.png
# inferencing: out138.png
# inferencing: out239.png
# inferencing: out269.png
# inferencing: out118.png
# inferencing: out50.png
# inferencing: out99.png
# inferencing: out335.png
# inferencing: out285.png
# inferencing: out90.png
# inferencing: out18.png
# inferencing: out250.png
# inferencing: out338.png
# inferencing: out39.png
# inferencing: out43.png
# inferencing: out3.png
# inferencing: out42.png
# inferencing: out205.png
# inferencing: out314.png
# inferencing: out343.png
# inferencing: out290.png
# inferencing: out151.png
# inferencing: out228.png
# inferencing: out294.png
# inferencing: out301.png
# inferencing: out309.png
# inferencing: out48.png
# inferencing: out164.png
# inferencing: out192.png
# inferencing: out41.png
# inferencing: out347.png
# inferencing: out109.png
# inferencing: out145.png
# inferencing: out320.png
# inferencing: out65.png
