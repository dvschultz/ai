# %% [markdown]
# <a href="https://colab.research.google.com/github/dvschultz/ai/blob/master/Aydao_CopyCropWeights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Make new PKLs from other (larger) PKLs
#
# Lightly documented process for generating pkl files from other pkls. This new version can crop files as long as they use the same layer count (using the same res_log2 count)
#
# Big big shout out to [@AydaoGMan on twitter](https://twitter.com/AydaoGMan) for supplying the code for this that I’m cutting up to put in this notebook!

# %% [markdown]
# ##Install libraries and dependencies

# %%
# %tensorflow_version 1.x

# !git clone https://github.com/aydao/stylegan2-surgery
# %cd stylegan2-surgery/
# Out:
# TensorFlow 1.x selected.
# Cloning into 'stylegan2-surgery'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 1399 (delta 11), reused 14 (delta 6), pack-reused 1370
# Receiving objects: 100% (1399/1399), 13.71 MiB | 15.72 MiB/s, done.
# Resolving deltas: 100% (951/951), done.
# /content/stylegan2-surgery

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
import sys, getopt, os

import numpy as np
import dnnlib
import dnnlib.tflib as tflib
from dnnlib.tflib import tfutil
from dnnlib.tflib.autosummary import autosummary

from training import dataset
from training import misc
import pickle
import argparse

# Note well that the argument order is target then source  
def copy_and_crop_trainables_from(target_net, source_net) -> None:
    for name in target_net.trainables.keys():
        if name not in source_net.trainables:
            print("Not restoring (not present):     {}".format(name))
        elif target_net.trainables[name].shape != source_net.trainables[name].shape:
            print("Not restoring (different shape): {}".format(name))
        elif name in source_net.trainables and target_net.trainables[name].shape == source_net.trainables[name].shape:
            print("Restoring: {}".format(name))
    source_trainables = source_net.trainables.keys()
    target_trainables = target_net.trainables.keys()
    names = [pair for pair in zip(source_trainables, target_trainables)]
            
    skip = []
    for pair in names:
        source_name, target_name = pair
        x = source_net.get_var(source_name)
        y = target_net.get_var(target_name)
        source_shape = x.shape
        target_shape = y.shape
        if source_shape != target_shape:
            update = x
            index = None 
            if 'Dense' in source_name:
                index = 0
                gap = source_shape[index] - target_shape[index]
                start = abs(gap) // 2
                end = start + target_shape[index]
                update = update[start:end,:]
            else:
                if source_shape[2] != target_shape[2]:
                    index = 2
                    gap = source_shape[index] - target_shape[index]
                    start = abs(gap) // 2
                    end = start + target_shape[index]
                    update = update[:,:,start:end,:]
                if source_shape[3] != target_shape[3]:
                    index = 3
                    gap = source_shape[index] - target_shape[index]
                    start = abs(gap) // 2
                    end = start + target_shape[index]
                    update = update[:,:,:,start:end]

            target_net.set_var(target_name, update)
            skip.append(source_name)

    weights_to_copy = {target_net.vars[pair[1]]: source_net.vars[pair[0]] for pair in names if pair[0] not in skip}
    tfutil.set_vars(tfutil.run(weights_to_copy))

def copy_weights(source_pkl,target_pkl,output_pkl):

    tflib.init_tf()

    with tf.Session() as sess:
        with tf.device('/gpu:0'):

            sourceG, sourceD, sourceGs = pickle.load(open(source_pkl, 'rb'))
            targetG, targetD, targetGs = pickle.load(open(target_pkl, 'rb'))
            
            print('Source:')
            sourceG.print_layers()
            sourceD.print_layers() 
            sourceGs.print_layers()
            
            print('Target:')
            targetG.print_layers()
            targetD.print_layers() 
            targetGs.print_layers()
            
            copy_and_crop_trainables_from(targetG, sourceG)
            copy_and_crop_trainables_from(targetD, sourceD)
            copy_and_crop_trainables_from(targetGs, sourceGs)
            
            misc.save_pkl((targetG, targetD, targetGs), os.path.join('./', output_pkl))

# %% [markdown]
# ##Conversion
#
# Steps to produce:
# 1. Create a pkl that is 1/2 the size of your current model (You can do this by starting a new model in the skyflynil repo). Grab the network-snapshot-00000.pkl and bring it into Colab.
# 2. Import your already trained pkl
# 3. Run the command below and swap out the paths. (First path is the pretrained model, Second path is the empty, half-scale model.)

# %%
# !gdown --id 1W9DJy51SHWyYbdGi72NH37_ahlkOzmXi -O /content/w.pkl
# !gdown --id 1ZqXxZxwDU0LO0NPCUxKbz0BmtJqguaA8 -O /content/glitch.pkl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1W9DJy51SHWyYbdGi72NH37_ahlkOzmXi
# To: /content/w.pkl
# 379MB [00:04, 85.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZqXxZxwDU0LO0NPCUxKbz0BmtJqguaA8
# To: /content/glitch.pkl
# 379MB [00:05, 71.4MB/s]

# %%
# !gdown --id 1bXUQyWn5IAAz8k6pE9sKghIHSn1Ee0uq -O /content/smaller.pkl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bXUQyWn5IAAz8k6pE9sKghIHSn1Ee0uq
# To: /content/smaller.pkl
# 372MB [00:03, 98.0MB/s]

# %%
copy_weights('/content/w.pkl','/content/smaller.pkl','/content/copied.pkl')
# Out:
# Source:
#
# G                              Params    OutputShape         WeightShape
# ---                            ---       ---                 ---
# latents_in                     -         (?, 512)            -
# labels_in                      -         (?, 0)              -
# lod                            -         ()                  -
# dlatent_avg                    -         (512,)              -
# G_mapping/latents_in           -         (?, 512)            -
# G_mapping/labels_in            -         (?, 0)              -
# G_mapping/Normalize            -         (?, 512)            -
# G_mapping/Dense0               262656    (?, 512)            (512, 512)
# G_mapping/Dense1               262656    (?, 512)            (512, 512)
# G_mapping/Dense2               262656    (?, 512)            (512, 512)
# G_mapping/Dense3               262656    (?, 512)            (512, 512)
# G_mapping/Dense4               262656    (?, 512)            (512, 512)
# G_mapping/Dense5               262656    (?, 512)            (512, 512)
# G_mapping/Dense6               262656    (?, 512)            (512, 512)
# G_mapping/Dense7               262656    (?, 512)            (512, 512)
# G_mapping/Broadcast            -         (?, 18, 512)        -
# G_mapping/dlatents_out         -         (?, 18, 512)        -
# Truncation/Lerp                -         (?, 18, 512)        -
# G_synthesis/dlatents_in        -         (?, 18, 512)        -
# G_synthesis/5x3/Const          7680      (?, 512, 5, 3)      (1, 512, 5, 3)
# G_synthesis/5x3/Conv           2622465   (?, 512, 5, 3)      (3, 3, 512, 512)
# G_synthesis/5x3/ToRGB          264195    (?, 3, 5, 3)        (1, 1, 512, 3)
# G_synthesis/10x6/Conv0_up      2622465   (?, 512, 10, 6)     (3, 3, 512, 512)
# G_synthesis/10x6/Conv1         2622465   (?, 512, 10, 6)     (3, 3, 512, 512)
# G_synthesis/10x6/Upsample      -         (?, 3, 10, 6)       -
# G_synthesis/10x6/ToRGB         264195    (?, 3, 10, 6)       (1, 1, 512, 3)
# G_synthesis/20x12/Conv0_up     2622465   (?, 512, 20, 12)    (3, 3, 512, 512)
# G_synthesis/20x12/Conv1        2622465   (?, 512, 20, 12)    (3, 3, 512, 512)
# G_synthesis/20x12/Upsample     -         (?, 3, 20, 12)      -
# G_synthesis/20x12/ToRGB        264195    (?, 3, 20, 12)      (1, 1, 512, 3)
# G_synthesis/40x24/Conv0_up     2622465   (?, 512, 40, 24)    (3, 3, 512, 512)
# G_synthesis/40x24/Conv1        2622465   (?, 512, 40, 24)    (3, 3, 512, 512)
# G_synthesis/40x24/Upsample     -         (?, 3, 40, 24)      -
# G_synthesis/40x24/ToRGB        264195    (?, 3, 40, 24)      (1, 1, 512, 3)
# G_synthesis/80x48/Conv0_up     2622465   (?, 512, 80, 48)    (3, 3, 512, 512)
# G_synthesis/80x48/Conv1        2622465   (?, 512, 80, 48)    (3, 3, 512, 512)
# G_synthesis/80x48/Upsample     -         (?, 3, 80, 48)      -
# G_synthesis/80x48/ToRGB        264195    (?, 3, 80, 48)      (1, 1, 512, 3)
# G_synthesis/160x96/Conv0_up    1442561   (?, 256, 160, 96)   (3, 3, 512, 256)
# G_synthesis/160x96/Conv1       721409    (?, 256, 160, 96)   (3, 3, 256, 256)
# G_synthesis/160x96/Upsample    -         (?, 3, 160, 96)     -
# G_synthesis/160x96/ToRGB       132099    (?, 3, 160, 96)     (1, 1, 256, 3)
# G_synthesis/320x192/Conv0_up   426369    (?, 128, 320, 192)  (3, 3, 256, 128)
# G_synthesis/320x192/Conv1      213249    (?, 128, 320, 192)  (3, 3, 128, 128)
# G_synthesis/320x192/Upsample   -         (?, 3, 320, 192)    -
# G_synthesis/320x192/ToRGB      66051     (?, 3, 320, 192)    (1, 1, 128, 3)
# G_synthesis/640x384/Conv0_up   139457    (?, 64, 640, 384)   (3, 3, 128, 64)
# G_synthesis/640x384/Conv1      69761     (?, 64, 640, 384)   (3, 3, 64, 64)
# G_synthesis/640x384/Upsample   -         (?, 3, 640, 384)    -
# G_synthesis/640x384/ToRGB      33027     (?, 3, 640, 384)    (1, 1, 64, 3)
# G_synthesis/1280x768/Conv0_up  51297     (?, 32, 1280, 768)  (3, 3, 64, 32)
# G_synthesis/1280x768/Conv1     25665     (?, 32, 1280, 768)  (3, 3, 32, 32)
# G_synthesis/1280x768/Upsample  -         (?, 3, 1280, 768)   -
# G_synthesis/1280x768/ToRGB     16515     (?, 3, 1280, 768)   (1, 1, 32, 3)
# G_synthesis/images_out         -         (?, 3, 1280, 768)   -
# G_synthesis/noise0             -         (1, 1, 5, 3)        -
# G_synthesis/noise1             -         (1, 1, 10, 6)       -
# G_synthesis/noise2             -         (1, 1, 10, 6)       -
# G_synthesis/noise3             -         (1, 1, 20, 12)      -
# G_synthesis/noise4             -         (1, 1, 20, 12)      -
# G_synthesis/noise5             -         (1, 1, 40, 24)      -
# G_synthesis/noise6             -         (1, 1, 40, 24)      -
# G_synthesis/noise7             -         (1, 1, 80, 48)      -
# G_synthesis/noise8             -         (1, 1, 80, 48)      -
# G_synthesis/noise9             -         (1, 1, 160, 96)     -
# G_synthesis/noise10            -         (1, 1, 160, 96)     -
# G_synthesis/noise11            -         (1, 1, 320, 192)    -
# G_synthesis/noise12            -         (1, 1, 320, 192)    -
# G_synthesis/noise13            -         (1, 1, 640, 384)    -
# G_synthesis/noise14            -         (1, 1, 640, 384)    -
# G_synthesis/noise15            -         (1, 1, 1280, 768)   -
# G_synthesis/noise16            -         (1, 1, 1280, 768)   -
# images_out                     -         (?, 3, 1280, 768)   -
# ---                            ---       ---                 ---
# Total                          30369548
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 1280, 768)   -
# labels_in            -         (?, 0)              -
# 1280x768/FromRGB     128       (?, 32, 1280, 768)  (1, 1, 3, 32)
# 1280x768/Conv0       9248      (?, 32, 1280, 768)  (3, 3, 32, 32)
# 1280x768/Conv1_down  18496     (?, 64, 640, 384)   (3, 3, 32, 64)
# 1280x768/Skip        2048      (?, 64, 640, 384)   (1, 1, 32, 64)
# 640x384/Conv0        36928     (?, 64, 640, 384)   (3, 3, 64, 64)
# 640x384/Conv1_down   73856     (?, 128, 320, 192)  (3, 3, 64, 128)
# 640x384/Skip         8192      (?, 128, 320, 192)  (1, 1, 64, 128)
# 320x192/Conv0        147584    (?, 128, 320, 192)  (3, 3, 128, 128)
# 320x192/Conv1_down   295168    (?, 256, 160, 96)   (3, 3, 128, 256)
# 320x192/Skip         32768     (?, 256, 160, 96)   (1, 1, 128, 256)
# 160x96/Conv0         590080    (?, 256, 160, 96)   (3, 3, 256, 256)
# 160x96/Conv1_down    1180160   (?, 512, 80, 48)    (3, 3, 256, 512)
# 160x96/Skip          131072    (?, 512, 80, 48)    (1, 1, 256, 512)
# 80x48/Conv0          2359808   (?, 512, 80, 48)    (3, 3, 512, 512)
# 80x48/Conv1_down     2359808   (?, 512, 40, 24)    (3, 3, 512, 512)
# 80x48/Skip           262144    (?, 512, 40, 24)    (1, 1, 512, 512)
# 40x24/Conv0          2359808   (?, 512, 40, 24)    (3, 3, 512, 512)
# 40x24/Conv1_down     2359808   (?, 512, 20, 12)    (3, 3, 512, 512)
# 40x24/Skip           262144    (?, 512, 20, 12)    (1, 1, 512, 512)
# 20x12/Conv0          2359808   (?, 512, 20, 12)    (3, 3, 512, 512)
# 20x12/Conv1_down     2359808   (?, 512, 10, 6)     (3, 3, 512, 512)
# 20x12/Skip           262144    (?, 512, 10, 6)     (1, 1, 512, 512)
# 10x6/Conv0           2359808   (?, 512, 10, 6)     (3, 3, 512, 512)
# 10x6/Conv1_down      2359808   (?, 512, 5, 3)      (3, 3, 512, 512)
# 10x6/Skip            262144    (?, 512, 5, 3)      (1, 1, 512, 512)
# 5x3/MinibatchStddev  -         (?, 513, 5, 3)      -
# 5x3/Conv             2364416   (?, 512, 5, 3)      (3, 3, 513, 512)
# 5x3/Dense0           3932672   (?, 512)            (7680, 512)
# Output               513       (?, 1)              (512, 1)
# scores_out           -         (?, 1)              -
# ---                  ---       ---                 ---
# Total                28750369
#
#
# Gs                             Params    OutputShape         WeightShape
# ---                            ---       ---                 ---
# latents_in                     -         (?, 512)            -
# labels_in                      -         (?, 0)              -
# lod                            -         ()                  -
# dlatent_avg                    -         (512,)              -
# G_mapping/latents_in           -         (?, 512)            -
# G_mapping/labels_in            -         (?, 0)              -
# G_mapping/Normalize            -         (?, 512)            -
# G_mapping/Dense0               262656    (?, 512)            (512, 512)
# G_mapping/Dense1               262656    (?, 512)            (512, 512)
# G_mapping/Dense2               262656    (?, 512)            (512, 512)
# G_mapping/Dense3               262656    (?, 512)            (512, 512)
# G_mapping/Dense4               262656    (?, 512)            (512, 512)
# G_mapping/Dense5               262656    (?, 512)            (512, 512)
# G_mapping/Dense6               262656    (?, 512)            (512, 512)
# G_mapping/Dense7               262656    (?, 512)            (512, 512)
# G_mapping/Broadcast            -         (?, 18, 512)        -
# G_mapping/dlatents_out         -         (?, 18, 512)        -
# Truncation/Lerp                -         (?, 18, 512)        -
# G_synthesis/dlatents_in        -         (?, 18, 512)        -
# G_synthesis/5x3/Const          7680      (?, 512, 5, 3)      (1, 512, 5, 3)
# G_synthesis/5x3/Conv           2622465   (?, 512, 5, 3)      (3, 3, 512, 512)
# G_synthesis/5x3/ToRGB          264195    (?, 3, 5, 3)        (1, 1, 512, 3)
# G_synthesis/10x6/Conv0_up      2622465   (?, 512, 10, 6)     (3, 3, 512, 512)
# G_synthesis/10x6/Conv1         2622465   (?, 512, 10, 6)     (3, 3, 512, 512)
# G_synthesis/10x6/Upsample      -         (?, 3, 10, 6)       -
# G_synthesis/10x6/ToRGB         264195    (?, 3, 10, 6)       (1, 1, 512, 3)
# G_synthesis/20x12/Conv0_up     2622465   (?, 512, 20, 12)    (3, 3, 512, 512)
# G_synthesis/20x12/Conv1        2622465   (?, 512, 20, 12)    (3, 3, 512, 512)
# G_synthesis/20x12/Upsample     -         (?, 3, 20, 12)      -
# G_synthesis/20x12/ToRGB        264195    (?, 3, 20, 12)      (1, 1, 512, 3)
# G_synthesis/40x24/Conv0_up     2622465   (?, 512, 40, 24)    (3, 3, 512, 512)
# G_synthesis/40x24/Conv1        2622465   (?, 512, 40, 24)    (3, 3, 512, 512)
# G_synthesis/40x24/Upsample     -         (?, 3, 40, 24)      -
# G_synthesis/40x24/ToRGB        264195    (?, 3, 40, 24)      (1, 1, 512, 3)
# G_synthesis/80x48/Conv0_up     2622465   (?, 512, 80, 48)    (3, 3, 512, 512)
# G_synthesis/80x48/Conv1        2622465   (?, 512, 80, 48)    (3, 3, 512, 512)
# G_synthesis/80x48/Upsample     -         (?, 3, 80, 48)      -
# G_synthesis/80x48/ToRGB        264195    (?, 3, 80, 48)      (1, 1, 512, 3)
# G_synthesis/160x96/Conv0_up    1442561   (?, 256, 160, 96)   (3, 3, 512, 256)
# G_synthesis/160x96/Conv1       721409    (?, 256, 160, 96)   (3, 3, 256, 256)
# G_synthesis/160x96/Upsample    -         (?, 3, 160, 96)     -
# G_synthesis/160x96/ToRGB       132099    (?, 3, 160, 96)     (1, 1, 256, 3)
# G_synthesis/320x192/Conv0_up   426369    (?, 128, 320, 192)  (3, 3, 256, 128)
# G_synthesis/320x192/Conv1      213249    (?, 128, 320, 192)  (3, 3, 128, 128)
# G_synthesis/320x192/Upsample   -         (?, 3, 320, 192)    -
# G_synthesis/320x192/ToRGB      66051     (?, 3, 320, 192)    (1, 1, 128, 3)
# G_synthesis/640x384/Conv0_up   139457    (?, 64, 640, 384)   (3, 3, 128, 64)
# G_synthesis/640x384/Conv1      69761     (?, 64, 640, 384)   (3, 3, 64, 64)
# G_synthesis/640x384/Upsample   -         (?, 3, 640, 384)    -
# G_synthesis/640x384/ToRGB      33027     (?, 3, 640, 384)    (1, 1, 64, 3)
# G_synthesis/1280x768/Conv0_up  51297     (?, 32, 1280, 768)  (3, 3, 64, 32)
# G_synthesis/1280x768/Conv1     25665     (?, 32, 1280, 768)  (3, 3, 32, 32)
# G_synthesis/1280x768/Upsample  -         (?, 3, 1280, 768)   -
# G_synthesis/1280x768/ToRGB     16515     (?, 3, 1280, 768)   (1, 1, 32, 3)
# G_synthesis/images_out         -         (?, 3, 1280, 768)   -
# G_synthesis/noise0             -         (1, 1, 5, 3)        -
# G_synthesis/noise1             -         (1, 1, 10, 6)       -
# G_synthesis/noise2             -         (1, 1, 10, 6)       -
# G_synthesis/noise3             -         (1, 1, 20, 12)      -
# G_synthesis/noise4             -         (1, 1, 20, 12)      -
# G_synthesis/noise5             -         (1, 1, 40, 24)      -
# G_synthesis/noise6             -         (1, 1, 40, 24)      -
# G_synthesis/noise7             -         (1, 1, 80, 48)      -
# G_synthesis/noise8             -         (1, 1, 80, 48)      -
# G_synthesis/noise9             -         (1, 1, 160, 96)     -
# G_synthesis/noise10            -         (1, 1, 160, 96)     -
# G_synthesis/noise11            -         (1, 1, 320, 192)    -
# G_synthesis/noise12            -         (1, 1, 320, 192)    -
# G_synthesis/noise13            -         (1, 1, 640, 384)    -
# G_synthesis/noise14            -         (1, 1, 640, 384)    -
# G_synthesis/noise15            -         (1, 1, 1280, 768)   -
# G_synthesis/noise16            -         (1, 1, 1280, 768)   -
# images_out                     -         (?, 3, 1280, 768)   -
# ---                            ---       ---                 ---
# Total                          30369548
#
# Target:
#
# G                              Params    OutputShape         WeightShape
# ---                            ---       ---                 ---
# latents_in                     -         (?, 512)            -
# labels_in                      -         (?, 0)              -
# lod                            -         ()                  -
# dlatent_avg                    -         (512,)              -
# G_mapping/latents_in           -         (?, 512)            -
# G_mapping/labels_in            -         (?, 0)              -
# G_mapping/Normalize            -         (?, 512)            -
# G_mapping/Dense0               262656    (?, 512)            (512, 512)
# G_mapping/Dense1               262656    (?, 512)            (512, 512)
# G_mapping/Dense2               262656    (?, 512)            (512, 512)
# G_mapping/Dense3               262656    (?, 512)            (512, 512)
# G_mapping/Dense4               262656    (?, 512)            (512, 512)
# G_mapping/Dense5               262656    (?, 512)            (512, 512)
# G_mapping/Dense6               262656    (?, 512)            (512, 512)
# G_mapping/Dense7               262656    (?, 512)            (512, 512)
# G_mapping/Broadcast            -         (?, 18, 512)        -
# G_mapping/dlatents_out         -         (?, 18, 512)        -
# Truncation/Lerp                -         (?, 18, 512)        -
# G_synthesis/dlatents_in        -         (?, 18, 512)        -
# G_synthesis/4x3/Const          6144      (?, 512, 4, 3)      (1, 512, 4, 3)
# G_synthesis/4x3/Conv           2622465   (?, 512, 4, 3)      (3, 3, 512, 512)
# G_synthesis/4x3/ToRGB          264195    (?, 3, 4, 3)        (1, 1, 512, 3)
# G_synthesis/8x6/Conv0_up       2622465   (?, 512, 8, 6)      (3, 3, 512, 512)
# G_synthesis/8x6/Conv1          2622465   (?, 512, 8, 6)      (3, 3, 512, 512)
# G_synthesis/8x6/Upsample       -         (?, 3, 8, 6)        -
# G_synthesis/8x6/ToRGB          264195    (?, 3, 8, 6)        (1, 1, 512, 3)
# G_synthesis/16x12/Conv0_up     2622465   (?, 512, 16, 12)    (3, 3, 512, 512)
# G_synthesis/16x12/Conv1        2622465   (?, 512, 16, 12)    (3, 3, 512, 512)
# G_synthesis/16x12/Upsample     -         (?, 3, 16, 12)      -
# G_synthesis/16x12/ToRGB        264195    (?, 3, 16, 12)      (1, 1, 512, 3)
# G_synthesis/32x24/Conv0_up     2622465   (?, 512, 32, 24)    (3, 3, 512, 512)
# G_synthesis/32x24/Conv1        2622465   (?, 512, 32, 24)    (3, 3, 512, 512)
# G_synthesis/32x24/Upsample     -         (?, 3, 32, 24)      -
# G_synthesis/32x24/ToRGB        264195    (?, 3, 32, 24)      (1, 1, 512, 3)
# G_synthesis/64x48/Conv0_up     2622465   (?, 512, 64, 48)    (3, 3, 512, 512)
# G_synthesis/64x48/Conv1        2622465   (?, 512, 64, 48)    (3, 3, 512, 512)
# G_synthesis/64x48/Upsample     -         (?, 3, 64, 48)      -
# G_synthesis/64x48/ToRGB        264195    (?, 3, 64, 48)      (1, 1, 512, 3)
# G_synthesis/128x96/Conv0_up    1442561   (?, 256, 128, 96)   (3, 3, 512, 256)
# G_synthesis/128x96/Conv1       721409    (?, 256, 128, 96)   (3, 3, 256, 256)
# G_synthesis/128x96/Upsample    -         (?, 3, 128, 96)     -
# G_synthesis/128x96/ToRGB       132099    (?, 3, 128, 96)     (1, 1, 256, 3)
# G_synthesis/256x192/Conv0_up   426369    (?, 128, 256, 192)  (3, 3, 256, 128)
# G_synthesis/256x192/Conv1      213249    (?, 128, 256, 192)  (3, 3, 128, 128)
# G_synthesis/256x192/Upsample   -         (?, 3, 256, 192)    -
# G_synthesis/256x192/ToRGB      66051     (?, 3, 256, 192)    (1, 1, 128, 3)
# G_synthesis/512x384/Conv0_up   139457    (?, 64, 512, 384)   (3, 3, 128, 64)
# G_synthesis/512x384/Conv1      69761     (?, 64, 512, 384)   (3, 3, 64, 64)
# G_synthesis/512x384/Upsample   -         (?, 3, 512, 384)    -
# G_synthesis/512x384/ToRGB      33027     (?, 3, 512, 384)    (1, 1, 64, 3)
# G_synthesis/1024x768/Conv0_up  51297     (?, 32, 1024, 768)  (3, 3, 64, 32)
# G_synthesis/1024x768/Conv1     25665     (?, 32, 1024, 768)  (3, 3, 32, 32)
# G_synthesis/1024x768/Upsample  -         (?, 3, 1024, 768)   -
# G_synthesis/1024x768/ToRGB     16515     (?, 3, 1024, 768)   (1, 1, 32, 3)
# G_synthesis/images_out         -         (?, 3, 1024, 768)   -
# G_synthesis/noise0             -         (1, 1, 4, 3)        -
# G_synthesis/noise1             -         (1, 1, 8, 6)        -
# G_synthesis/noise2             -         (1, 1, 8, 6)        -
# G_synthesis/noise3             -         (1, 1, 16, 12)      -
# G_synthesis/noise4             -         (1, 1, 16, 12)      -
# G_synthesis/noise5             -         (1, 1, 32, 24)      -
# G_synthesis/noise6             -         (1, 1, 32, 24)      -
# G_synthesis/noise7             -         (1, 1, 64, 48)      -
# G_synthesis/noise8             -         (1, 1, 64, 48)      -
# G_synthesis/noise9             -         (1, 1, 128, 96)     -
# G_synthesis/noise10            -         (1, 1, 128, 96)     -
# G_synthesis/noise11            -         (1, 1, 256, 192)    -
# G_synthesis/noise12            -         (1, 1, 256, 192)    -
# G_synthesis/noise13            -         (1, 1, 512, 384)    -
# G_synthesis/noise14            -         (1, 1, 512, 384)    -
# G_synthesis/noise15            -         (1, 1, 1024, 768)   -
# G_synthesis/noise16            -         (1, 1, 1024, 768)   -
# images_out                     -         (?, 3, 1024, 768)   -
# ---                            ---       ---                 ---
# Total                          30368012
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 1024, 768)   -
# labels_in            -         (?, 0)              -
# 1024x768/FromRGB     128       (?, 32, 1024, 768)  (1, 1, 3, 32)
# 1024x768/Conv0       9248      (?, 32, 1024, 768)  (3, 3, 32, 32)
# 1024x768/Conv1_down  18496     (?, 64, 512, 384)   (3, 3, 32, 64)
# 1024x768/Skip        2048      (?, 64, 512, 384)   (1, 1, 32, 64)
# 512x384/Conv0        36928     (?, 64, 512, 384)   (3, 3, 64, 64)
# 512x384/Conv1_down   73856     (?, 128, 256, 192)  (3, 3, 64, 128)
# 512x384/Skip         8192      (?, 128, 256, 192)  (1, 1, 64, 128)
# 256x192/Conv0        147584    (?, 128, 256, 192)  (3, 3, 128, 128)
# 256x192/Conv1_down   295168    (?, 256, 128, 96)   (3, 3, 128, 256)
# 256x192/Skip         32768     (?, 256, 128, 96)   (1, 1, 128, 256)
# 128x96/Conv0         590080    (?, 256, 128, 96)   (3, 3, 256, 256)
# 128x96/Conv1_down    1180160   (?, 512, 64, 48)    (3, 3, 256, 512)
# 128x96/Skip          131072    (?, 512, 64, 48)    (1, 1, 256, 512)
# 64x48/Conv0          2359808   (?, 512, 64, 48)    (3, 3, 512, 512)
# 64x48/Conv1_down     2359808   (?, 512, 32, 24)    (3, 3, 512, 512)
# 64x48/Skip           262144    (?, 512, 32, 24)    (1, 1, 512, 512)
# 32x24/Conv0          2359808   (?, 512, 32, 24)    (3, 3, 512, 512)
# 32x24/Conv1_down     2359808   (?, 512, 16, 12)    (3, 3, 512, 512)
# 32x24/Skip           262144    (?, 512, 16, 12)    (1, 1, 512, 512)
# 16x12/Conv0          2359808   (?, 512, 16, 12)    (3, 3, 512, 512)
# 16x12/Conv1_down     2359808   (?, 512, 8, 6)      (3, 3, 512, 512)
# 16x12/Skip           262144    (?, 512, 8, 6)      (1, 1, 512, 512)
# 8x6/Conv0            2359808   (?, 512, 8, 6)      (3, 3, 512, 512)
# 8x6/Conv1_down       2359808   (?, 512, 4, 3)      (3, 3, 512, 512)
# 8x6/Skip             262144    (?, 512, 4, 3)      (1, 1, 512, 512)
# 4x3/MinibatchStddev  -         (?, 513, 4, 3)      -
# 4x3/Conv             2364416   (?, 512, 4, 3)      (3, 3, 513, 512)
# 4x3/Dense0           3146240   (?, 512)            (6144, 512)
# Output               513       (?, 1)              (512, 1)
# scores_out           -         (?, 1)              -
# ---                  ---       ---                 ---
# Total                27963937
#
#
# Gs                             Params    OutputShape         WeightShape
# ---                            ---       ---                 ---
# latents_in                     -         (?, 512)            -
# labels_in                      -         (?, 0)              -
# lod                            -         ()                  -
# dlatent_avg                    -         (512,)              -
# G_mapping/latents_in           -         (?, 512)            -
# G_mapping/labels_in            -         (?, 0)              -
# G_mapping/Normalize            -         (?, 512)            -
# G_mapping/Dense0               262656    (?, 512)            (512, 512)
# G_mapping/Dense1               262656    (?, 512)            (512, 512)
# G_mapping/Dense2               262656    (?, 512)            (512, 512)
# G_mapping/Dense3               262656    (?, 512)            (512, 512)
# G_mapping/Dense4               262656    (?, 512)            (512, 512)
# G_mapping/Dense5               262656    (?, 512)            (512, 512)
# G_mapping/Dense6               262656    (?, 512)            (512, 512)
# G_mapping/Dense7               262656    (?, 512)            (512, 512)
# G_mapping/Broadcast            -         (?, 18, 512)        -
# G_mapping/dlatents_out         -         (?, 18, 512)        -
# Truncation/Lerp                -         (?, 18, 512)        -
# G_synthesis/dlatents_in        -         (?, 18, 512)        -
# G_synthesis/4x3/Const          6144      (?, 512, 4, 3)      (1, 512, 4, 3)
# G_synthesis/4x3/Conv           2622465   (?, 512, 4, 3)      (3, 3, 512, 512)
# G_synthesis/4x3/ToRGB          264195    (?, 3, 4, 3)        (1, 1, 512, 3)
# G_synthesis/8x6/Conv0_up       2622465   (?, 512, 8, 6)      (3, 3, 512, 512)
# G_synthesis/8x6/Conv1          2622465   (?, 512, 8, 6)      (3, 3, 512, 512)
# G_synthesis/8x6/Upsample       -         (?, 3, 8, 6)        -
# G_synthesis/8x6/ToRGB          264195    (?, 3, 8, 6)        (1, 1, 512, 3)
# G_synthesis/16x12/Conv0_up     2622465   (?, 512, 16, 12)    (3, 3, 512, 512)
# G_synthesis/16x12/Conv1        2622465   (?, 512, 16, 12)    (3, 3, 512, 512)
# G_synthesis/16x12/Upsample     -         (?, 3, 16, 12)      -
# G_synthesis/16x12/ToRGB        264195    (?, 3, 16, 12)      (1, 1, 512, 3)
# G_synthesis/32x24/Conv0_up     2622465   (?, 512, 32, 24)    (3, 3, 512, 512)
# G_synthesis/32x24/Conv1        2622465   (?, 512, 32, 24)    (3, 3, 512, 512)
# G_synthesis/32x24/Upsample     -         (?, 3, 32, 24)      -
# G_synthesis/32x24/ToRGB        264195    (?, 3, 32, 24)      (1, 1, 512, 3)
# G_synthesis/64x48/Conv0_up     2622465   (?, 512, 64, 48)    (3, 3, 512, 512)
# G_synthesis/64x48/Conv1        2622465   (?, 512, 64, 48)    (3, 3, 512, 512)
# G_synthesis/64x48/Upsample     -         (?, 3, 64, 48)      -
# G_synthesis/64x48/ToRGB        264195    (?, 3, 64, 48)      (1, 1, 512, 3)
# G_synthesis/128x96/Conv0_up    1442561   (?, 256, 128, 96)   (3, 3, 512, 256)
# G_synthesis/128x96/Conv1       721409    (?, 256, 128, 96)   (3, 3, 256, 256)
# G_synthesis/128x96/Upsample    -         (?, 3, 128, 96)     -
# G_synthesis/128x96/ToRGB       132099    (?, 3, 128, 96)     (1, 1, 256, 3)
# G_synthesis/256x192/Conv0_up   426369    (?, 128, 256, 192)  (3, 3, 256, 128)
# G_synthesis/256x192/Conv1      213249    (?, 128, 256, 192)  (3, 3, 128, 128)
# G_synthesis/256x192/Upsample   -         (?, 3, 256, 192)    -
# G_synthesis/256x192/ToRGB      66051     (?, 3, 256, 192)    (1, 1, 128, 3)
# G_synthesis/512x384/Conv0_up   139457    (?, 64, 512, 384)   (3, 3, 128, 64)
# G_synthesis/512x384/Conv1      69761     (?, 64, 512, 384)   (3, 3, 64, 64)
# G_synthesis/512x384/Upsample   -         (?, 3, 512, 384)    -
# G_synthesis/512x384/ToRGB      33027     (?, 3, 512, 384)    (1, 1, 64, 3)
# G_synthesis/1024x768/Conv0_up  51297     (?, 32, 1024, 768)  (3, 3, 64, 32)
# G_synthesis/1024x768/Conv1     25665     (?, 32, 1024, 768)  (3, 3, 32, 32)
# G_synthesis/1024x768/Upsample  -         (?, 3, 1024, 768)   -
# G_synthesis/1024x768/ToRGB     16515     (?, 3, 1024, 768)   (1, 1, 32, 3)
# G_synthesis/images_out         -         (?, 3, 1024, 768)   -
# G_synthesis/noise0             -         (1, 1, 4, 3)        -
# G_synthesis/noise1             -         (1, 1, 8, 6)        -
# G_synthesis/noise2             -         (1, 1, 8, 6)        -
# G_synthesis/noise3             -         (1, 1, 16, 12)      -
# G_synthesis/noise4             -         (1, 1, 16, 12)      -
# G_synthesis/noise5             -         (1, 1, 32, 24)      -
# G_synthesis/noise6             -         (1, 1, 32, 24)      -
# G_synthesis/noise7             -         (1, 1, 64, 48)      -
# G_synthesis/noise8             -         (1, 1, 64, 48)      -
# G_synthesis/noise9             -         (1, 1, 128, 96)     -
# G_synthesis/noise10            -         (1, 1, 128, 96)     -
# G_synthesis/noise11            -         (1, 1, 256, 192)    -
# G_synthesis/noise12            -         (1, 1, 256, 192)    -
# G_synthesis/noise13            -         (1, 1, 512, 384)    -
# G_synthesis/noise14            -         (1, 1, 512, 384)    -
# G_synthesis/noise15            -         (1, 1, 1024, 768)   -
# G_synthesis/noise16            -         (1, 1, 1024, 768)   -
# images_out                     -         (?, 3, 1024, 768)   -
# ---                            ---       ---                 ---
# Total                          30368012
#
# Not restoring (not present):     G_synthesis/4x3/Const/const
# Not restoring (not present):     G_synthesis/4x3/Conv/weight
# Not restoring (not present):     G_synthesis/4x3/Conv/mod_weight
# Not restoring (not present):     G_synthesis/4x3/Conv/mod_bias
# Not restoring (not present):     G_synthesis/4x3/Conv/noise_strength
# Not restoring (not present):     G_synthesis/4x3/Conv/bias
# Not restoring (not present):     G_synthesis/4x3/ToRGB/weight
# Not restoring (not present):     G_synthesis/4x3/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/4x3/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/4x3/ToRGB/bias
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/weight
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/bias
# Not restoring (not present):     G_synthesis/8x6/Conv1/weight
# Not restoring (not present):     G_synthesis/8x6/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/8x6/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/8x6/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/8x6/Conv1/bias
# Not restoring (not present):     G_synthesis/8x6/ToRGB/weight
# Not restoring (not present):     G_synthesis/8x6/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/8x6/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/8x6/ToRGB/bias
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/weight
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/bias
# Not restoring (not present):     G_synthesis/16x12/Conv1/weight
# Not restoring (not present):     G_synthesis/16x12/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/16x12/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/16x12/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/16x12/Conv1/bias
# Not restoring (not present):     G_synthesis/16x12/ToRGB/weight
# Not restoring (not present):     G_synthesis/16x12/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/16x12/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/16x12/ToRGB/bias
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/weight
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/bias
# Not restoring (not present):     G_synthesis/32x24/Conv1/weight
# Not restoring (not present):     G_synthesis/32x24/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/32x24/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/32x24/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/32x24/Conv1/bias
# Not restoring (not present):     G_synthesis/32x24/ToRGB/weight
# Not restoring (not present):     G_synthesis/32x24/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/32x24/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/32x24/ToRGB/bias
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/weight
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/bias
# Not restoring (not present):     G_synthesis/64x48/Conv1/weight
# Not restoring (not present):     G_synthesis/64x48/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/64x48/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/64x48/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/64x48/Conv1/bias
# Not restoring (not present):     G_synthesis/64x48/ToRGB/weight
# Not restoring (not present):     G_synthesis/64x48/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/64x48/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/64x48/ToRGB/bias
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/weight
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/bias
# Not restoring (not present):     G_synthesis/128x96/Conv1/weight
# Not restoring (not present):     G_synthesis/128x96/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/128x96/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/128x96/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/128x96/Conv1/bias
# Not restoring (not present):     G_synthesis/128x96/ToRGB/weight
# Not restoring (not present):     G_synthesis/128x96/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/128x96/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/128x96/ToRGB/bias
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/weight
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/bias
# Not restoring (not present):     G_synthesis/256x192/Conv1/weight
# Not restoring (not present):     G_synthesis/256x192/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/256x192/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/256x192/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/256x192/Conv1/bias
# Not restoring (not present):     G_synthesis/256x192/ToRGB/weight
# Not restoring (not present):     G_synthesis/256x192/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/256x192/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/256x192/ToRGB/bias
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/weight
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/bias
# Not restoring (not present):     G_synthesis/512x384/Conv1/weight
# Not restoring (not present):     G_synthesis/512x384/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/512x384/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/512x384/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/512x384/Conv1/bias
# Not restoring (not present):     G_synthesis/512x384/ToRGB/weight
# Not restoring (not present):     G_synthesis/512x384/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/512x384/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/512x384/ToRGB/bias
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/weight
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/bias
# Not restoring (not present):     G_synthesis/1024x768/Conv1/weight
# Not restoring (not present):     G_synthesis/1024x768/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/1024x768/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/1024x768/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/1024x768/Conv1/bias
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/weight
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/bias
# Restoring: G_mapping/Dense0/weight
# Restoring: G_mapping/Dense0/bias
# Restoring: G_mapping/Dense1/weight
# Restoring: G_mapping/Dense1/bias
# Restoring: G_mapping/Dense2/weight
# Restoring: G_mapping/Dense2/bias
# Restoring: G_mapping/Dense3/weight
# Restoring: G_mapping/Dense3/bias
# Restoring: G_mapping/Dense4/weight
# Restoring: G_mapping/Dense4/bias
# Restoring: G_mapping/Dense5/weight
# Restoring: G_mapping/Dense5/bias
# Restoring: G_mapping/Dense6/weight
# Restoring: G_mapping/Dense6/bias
# Restoring: G_mapping/Dense7/weight
# Restoring: G_mapping/Dense7/bias
# Not restoring (not present):     1024x768/FromRGB/weight
# Not restoring (not present):     1024x768/FromRGB/bias
# Not restoring (not present):     1024x768/Conv0/weight
# Not restoring (not present):     1024x768/Conv0/bias
# Not restoring (not present):     1024x768/Conv1_down/weight
# Not restoring (not present):     1024x768/Conv1_down/bias
# Not restoring (not present):     1024x768/Skip/weight
# Not restoring (not present):     512x384/Conv0/weight
# Not restoring (not present):     512x384/Conv0/bias
# Not restoring (not present):     512x384/Conv1_down/weight
# Not restoring (not present):     512x384/Conv1_down/bias
# Not restoring (not present):     512x384/Skip/weight
# Not restoring (not present):     256x192/Conv0/weight
# Not restoring (not present):     256x192/Conv0/bias
# Not restoring (not present):     256x192/Conv1_down/weight
# Not restoring (not present):     256x192/Conv1_down/bias
# Not restoring (not present):     256x192/Skip/weight
# Not restoring (not present):     128x96/Conv0/weight
# Not restoring (not present):     128x96/Conv0/bias
# Not restoring (not present):     128x96/Conv1_down/weight
# Not restoring (not present):     128x96/Conv1_down/bias
# Not restoring (not present):     128x96/Skip/weight
# Not restoring (not present):     64x48/Conv0/weight
# Not restoring (not present):     64x48/Conv0/bias
# Not restoring (not present):     64x48/Conv1_down/weight
# Not restoring (not present):     64x48/Conv1_down/bias
# Not restoring (not present):     64x48/Skip/weight
# Not restoring (not present):     32x24/Conv0/weight
# Not restoring (not present):     32x24/Conv0/bias
# Not restoring (not present):     32x24/Conv1_down/weight
# Not restoring (not present):     32x24/Conv1_down/bias
# Not restoring (not present):     32x24/Skip/weight
# Not restoring (not present):     16x12/Conv0/weight
# Not restoring (not present):     16x12/Conv0/bias
# Not restoring (not present):     16x12/Conv1_down/weight
# Not restoring (not present):     16x12/Conv1_down/bias
# Not restoring (not present):     16x12/Skip/weight
# Not restoring (not present):     8x6/Conv0/weight
# Not restoring (not present):     8x6/Conv0/bias
# Not restoring (not present):     8x6/Conv1_down/weight
# Not restoring (not present):     8x6/Conv1_down/bias
# Not restoring (not present):     8x6/Skip/weight
# Not restoring (not present):     4x3/Conv/weight
# Not restoring (not present):     4x3/Conv/bias
# Not restoring (not present):     4x3/Dense0/weight
# Not restoring (not present):     4x3/Dense0/bias
# Restoring: Output/weight
# Restoring: Output/bias
# Not restoring (not present):     G_synthesis/4x3/Const/const
# Not restoring (not present):     G_synthesis/4x3/Conv/weight
# Not restoring (not present):     G_synthesis/4x3/Conv/mod_weight
# Not restoring (not present):     G_synthesis/4x3/Conv/mod_bias
# Not restoring (not present):     G_synthesis/4x3/Conv/noise_strength
# Not restoring (not present):     G_synthesis/4x3/Conv/bias
# Not restoring (not present):     G_synthesis/4x3/ToRGB/weight
# Not restoring (not present):     G_synthesis/4x3/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/4x3/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/4x3/ToRGB/bias
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/weight
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/8x6/Conv0_up/bias
# Not restoring (not present):     G_synthesis/8x6/Conv1/weight
# Not restoring (not present):     G_synthesis/8x6/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/8x6/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/8x6/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/8x6/Conv1/bias
# Not restoring (not present):     G_synthesis/8x6/ToRGB/weight
# Not restoring (not present):     G_synthesis/8x6/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/8x6/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/8x6/ToRGB/bias
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/weight
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/16x12/Conv0_up/bias
# Not restoring (not present):     G_synthesis/16x12/Conv1/weight
# Not restoring (not present):     G_synthesis/16x12/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/16x12/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/16x12/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/16x12/Conv1/bias
# Not restoring (not present):     G_synthesis/16x12/ToRGB/weight
# Not restoring (not present):     G_synthesis/16x12/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/16x12/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/16x12/ToRGB/bias
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/weight
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/32x24/Conv0_up/bias
# Not restoring (not present):     G_synthesis/32x24/Conv1/weight
# Not restoring (not present):     G_synthesis/32x24/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/32x24/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/32x24/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/32x24/Conv1/bias
# Not restoring (not present):     G_synthesis/32x24/ToRGB/weight
# Not restoring (not present):     G_synthesis/32x24/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/32x24/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/32x24/ToRGB/bias
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/weight
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/64x48/Conv0_up/bias
# Not restoring (not present):     G_synthesis/64x48/Conv1/weight
# Not restoring (not present):     G_synthesis/64x48/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/64x48/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/64x48/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/64x48/Conv1/bias
# Not restoring (not present):     G_synthesis/64x48/ToRGB/weight
# Not restoring (not present):     G_synthesis/64x48/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/64x48/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/64x48/ToRGB/bias
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/weight
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/128x96/Conv0_up/bias
# Not restoring (not present):     G_synthesis/128x96/Conv1/weight
# Not restoring (not present):     G_synthesis/128x96/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/128x96/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/128x96/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/128x96/Conv1/bias
# Not restoring (not present):     G_synthesis/128x96/ToRGB/weight
# Not restoring (not present):     G_synthesis/128x96/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/128x96/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/128x96/ToRGB/bias
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/weight
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/256x192/Conv0_up/bias
# Not restoring (not present):     G_synthesis/256x192/Conv1/weight
# Not restoring (not present):     G_synthesis/256x192/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/256x192/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/256x192/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/256x192/Conv1/bias
# Not restoring (not present):     G_synthesis/256x192/ToRGB/weight
# Not restoring (not present):     G_synthesis/256x192/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/256x192/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/256x192/ToRGB/bias
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/weight
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/512x384/Conv0_up/bias
# Not restoring (not present):     G_synthesis/512x384/Conv1/weight
# Not restoring (not present):     G_synthesis/512x384/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/512x384/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/512x384/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/512x384/Conv1/bias
# Not restoring (not present):     G_synthesis/512x384/ToRGB/weight
# Not restoring (not present):     G_synthesis/512x384/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/512x384/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/512x384/ToRGB/bias
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/weight
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/mod_weight
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/mod_bias
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/noise_strength
# Not restoring (not present):     G_synthesis/1024x768/Conv0_up/bias
# Not restoring (not present):     G_synthesis/1024x768/Conv1/weight
# Not restoring (not present):     G_synthesis/1024x768/Conv1/mod_weight
# Not restoring (not present):     G_synthesis/1024x768/Conv1/mod_bias
# Not restoring (not present):     G_synthesis/1024x768/Conv1/noise_strength
# Not restoring (not present):     G_synthesis/1024x768/Conv1/bias
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/weight
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/mod_weight
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/mod_bias
# Not restoring (not present):     G_synthesis/1024x768/ToRGB/bias
# Restoring: G_mapping/Dense0/weight
# Restoring: G_mapping/Dense0/bias
# Restoring: G_mapping/Dense1/weight
# Restoring: G_mapping/Dense1/bias
# Restoring: G_mapping/Dense2/weight
# Restoring: G_mapping/Dense2/bias
# Restoring: G_mapping/Dense3/weight
# Restoring: G_mapping/Dense3/bias
# Restoring: G_mapping/Dense4/weight
# Restoring: G_mapping/Dense4/bias
# Restoring: G_mapping/Dense5/weight
# Restoring: G_mapping/Dense5/bias
# Restoring: G_mapping/Dense6/weight
# Restoring: G_mapping/Dense6/bias
# Restoring: G_mapping/Dense7/weight
# Restoring: G_mapping/Dense7/bias

# %%
cd ../
# Out:
# /content/stylegan2-surgery

# %% [markdown]
# ## Testing it out

# %%
pwd
# Out:
# '/content/stylegan2-surgery'

# %%
# %cd ../
# !git clone https://github.com/dvschultz/stylegan2
# !pip install opensimplex
# %cd stylegan2
# Out:
# /content
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 282, done.
# remote: Total 282 (delta 0), reused 0 (delta 0), pack-reused 282
# Receiving objects: 100% (282/282), 15.27 MiB | 3.79 MiB/s, done.
# Resolving deltas: 100% (152/152), done.
# Collecting opensimplex
#   Downloading https://files.pythonhosted.org/packages/b9/28/25649c7258dd530aaf9a5c8a4bffeb08e6293ed3d4b671d44b985e8c28fa/opensimplex-0.2.tar.gz
# Building wheels for collected packages: opensimplex
#   Building wheel for opensimplex (setup.py) ... done
#   Created wheel for opensimplex: filename=opensimplex-0.2-cp36-none-any.whl size=14040 sha256=5c91bf1b5e852979197886a8eb0871205a8a78cc87275ad0d2e0963213114cd0
#   Stored in directory: /root/.cache/pip/wheels/d3/25/5a/f35e0ac92237c60db97e2f49536fca6d817b0f83340253abee
# Successfully built opensimplex
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.2
# /content/stylegan2

# %%
# !python run_generator.py generate-images --network=/content/copied.pkl --seeds=10-75 --truncation-psi=0.5
# Out:
# Local submit - run_dir: results/00000-generate-images
# dnnlib: Running run_generator.generate_images() on localhost...
# Loading networks from "/content/copied.pkl"...
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Compiling... Loading... Done.
# Generating image for seed 10 (0/66) ...
# Generating image for seed 11 (1/66) ...
# Generating image for seed 12 (2/66) ...
# Generating image for seed 13 (3/66) ...
# Generating image for seed 14 (4/66) ...
# Generating image for seed 15 (5/66) ...
# Generating image for seed 16 (6/66) ...
# Generating image for seed 17 (7/66) ...
# Generating image for seed 18 (8/66) ...
# Generating image for seed 19 (9/66) ...
# Generating image for seed 20 (10/66) ...
# Generating image for seed 21 (11/66) ...
# Generating image for seed 22 (12/66) ...
# Generating image for seed 23 (13/66) ...
# Generating image for seed 24 (14/66) ...
# Generating image for seed 25 (15/66) ...
# Generating image for seed 26 (16/66) ...
# Generating image for seed 27 (17/66) ...
# Generating image for seed 28 (18/66) ...
# Generating image for seed 29 (19/66) ...
# Generating image for seed 30 (20/66) ...
# Generating image for seed 31 (21/66) ...
# Generating image for seed 32 (22/66) ...
# Generating image for seed 33 (23/66) ...
# Generating image for seed 34 (24/66) ...
# Generating image for seed 35 (25/66) ...
# Generating image for seed 36 (26/66) ...
# Generating image for seed 37 (27/66) ...
# Generating image for seed 38 (28/66) ...
# Generating image for seed 39 (29/66) ...
# Generating image for seed 40 (30/66) ...
# Generating image for seed 41 (31/66) ...
# Generating image for seed 42 (32/66) ...
# Generating image for seed 43 (33/66) ...
# Generating image for seed 44 (34/66) ...
# Generating image for seed 45 (35/66) ...
# Generating image for seed 46 (36/66) ...
# Generating image for seed 47 (37/66) ...
# Generating image for seed 48 (38/66) ...
# Generating image for seed 49 (39/66) ...
# Generating image for seed 50 (40/66) ...
# Generating image for seed 51 (41/66) ...
# Generating image for seed 52 (42/66) ...
# Generating image for seed 53 (43/66) ...
# Generating image for seed 54 (44/66) ...
# Generating image for seed 55 (45/66) ...
# Generating image for seed 56 (46/66) ...
# Generating image for seed 57 (47/66) ...
# Generating image for seed 58 (48/66) ...
# Generating image for seed 59 (49/66) ...
# Generating image for seed 60 (50/66) ...
# Generating image for seed 61 (51/66) ...
# Generating image for seed 62 (52/66) ...
# Generating image for seed 63 (53/66) ...
# Generating image for seed 64 (54/66) ...
# Generating image for seed 65 (55/66) ...
# Generating image for seed 66 (56/66) ...
# Generating image for seed 67 (57/66) ...
# Generating image for seed 68 (58/66) ...
# Generating image for seed 69 (59/66) ...
# Generating image for seed 70 (60/66) ...
# Generating image for seed 71 (61/66) ...
# Generating image for seed 72 (62/66) ...
# Generating image for seed 73 (63/66) ...
# Generating image for seed 74 (64/66) ...
# Generating image for seed 75 (65/66) ...
# dnnlib: Finished run_generator.generate_images() in 1m 38s.
